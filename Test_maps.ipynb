# %%
#import packages
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import os

# %%
os.environ['HDF5_USE_FILE_LOCKING']='FALSE'
ds = xr.open_dataset('private/ffmcfile.nc')
print(ds)
# Out:
# <xarray.Dataset> Size: 0B
# Dimensions:  ()
# Data variables:
#     *empty*

# %%
df=ds.to_dataframe()
print(df[(df['time']==2)])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df=ds.to_dataframe()
#       2 print(df[(df['time']==2)])
#
# File /opt/conda/lib/python3.11/site-packages/xarray/core/dataset.py:7305, in Dataset.to_dataframe(self, dim_order)
#    7277 """Convert this dataset into a pandas.DataFrame.
#    7278
#    7279 Non-index variables in this dataset form the columns of the
#    (...)
#    7300
#    7301 """
#    7303 ordered_dims = self._normalize_dim_order(dim_order=dim_order)
# -> 7305 return self._to_dataframe(ordered_dims=ordered_dims)
#
# File /opt/conda/lib/python3.11/site-packages/xarray/core/dataset.py:7259, in Dataset._to_dataframe(self, ordered_dims)
#    7250 extension_array_columns = [
#    7251     k
#    7252     for k in columns_in_order
#    7253     if is_extension_array_dtype(self.variables[k].data)
#    7254 ]
#    7255 data = [
# ...

# %%
print(ds)
# Out:
# <xarray.Dataset> Size: 69MB
# Dimensions:  (lat: 280, lon: 386, time: 80)
# Coordinates:
#   * lat      (lat) float32 1kB 9.969e+36 9.969e+36 ... 9.969e+36 9.969e+36
#   * lon      (lon) float32 2kB 9.969e+36 9.969e+36 ... 9.969e+36 9.969e+36
# Dimensions without coordinates: time
# Data variables:
#     time64   (time) float64 640B ...
#     ffmc     (time, lat, lon) float64 69MB ...
# Attributes:
#     title:    ffmc_test

# %%
ds
# Out:
# <xarray.Dataset> Size: 69MB
# Dimensions:  (lat: 280, lon: 386, time: 80)
# Coordinates:
#   * lat      (lat) float32 1kB 9.969e+36 9.969e+36 ... 9.969e+36 9.969e+36
#   * lon      (lon) float32 2kB 9.969e+36 9.969e+36 ... 9.969e+36 9.969e+36
# Dimensions without coordinates: time
# Data variables:
#     time64   (time) float64 640B ...
#     ffmc     (time, lat, lon) float64 69MB ...
# Attributes:
#     title:    ffmc_test

# %%
# Out:
# <xarray.DataArray 'ffmc' (lat: 280, lon: 386)> Size: 865kB
# [108080 values with dtype=float64]
# Coordinates:
#   * lat      (lat) float32 1kB 9.969e+36 9.969e+36 ... 9.969e+36 9.969e+36
#   * lon      (lon) float32 2kB 9.969e+36 9.969e+36 ... 9.969e+36 9.969e+36
# Attributes:
#     units:    1

# %%
ds.ffmc[11,0,0]
# Out:
# <xarray.DataArray 'ffmc' ()> Size: 8B
# [1 values with dtype=float64]
# Coordinates:
#     lat      float32 4B 9.969e+36
#     lon      float32 4B 9.969e+36
#     time     float64 8B 9.969e+36
# Attributes:
#     units:    1

# %%
plt.figure()
plt.imshow(ds.ffmc[3,:,:])
